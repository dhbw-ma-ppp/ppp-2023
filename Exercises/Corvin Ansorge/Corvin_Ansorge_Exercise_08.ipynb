# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Importing data

# %%
file_path = "/Users/corvinansorge/PycharmProjects/ppp-2023/data/titanic.csv"

# %% [markdown]
# ## 1.General Data Exploration

# %%
df = pd.read_csv(file_path, delimiter=",")

df['Age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# This graph shows the survival rate of the different age groups.

# %%
df.groupby("Sex").mean("Survived").plot.bar(y="Survived")
# Out:
# <Axes: xlabel='Sex'>

# %%
df.groupby("Pclass").mean("Survived").plot.bar(y="Survived")
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>
